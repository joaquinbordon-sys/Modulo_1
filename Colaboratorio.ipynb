# %% [markdown]
# <a href="https://colab.research.google.com/github/joaquinbordon-sys/Modulo_1/blob/main/Colaboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este es mi primer cuaderno
#
# Aqui voy a mezclar codigo Markdown con operaciones matematica
#
# *   Sumar
# *   Restar
# *   Multiplicar
# *   Dividir

# %%
a=3
b=5
a+b
# Out:
# 8

# %%
a = np.arange(1, 101)
b = a * a

plt.plot(a, b, label="Presion del gas critico", color="blue")
plt.xlabel("Volumen")
plt.ylabel("Presion")
plt.title("Presion del gas critico")
plt.legend()
plt.grid(True)
plt.show()
